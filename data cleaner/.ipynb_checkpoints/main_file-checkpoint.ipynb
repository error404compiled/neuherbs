# %%
import pandas as pd 
import numpy as np

# %%
inp = input("Enter the file name : ")
csv1 = pd.read_csv(inp)
csv1.head()
# Out:
# Enter the file name : orders_export_1.csv
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (28,38,45,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#      Name                    Email Financial Status  \
# 0  #29914    pankajgavri@gmail.com             paid
# 1  #29913  aishpawar9428@gmail.com          pending
# 2  #29912    zuberali983@gmail.com             paid
# 3  #29911    zuberali983@gmail.com          pending
# 4  #29910  dr.ajaychauhan@yahoo.in          pending
#
#                      Paid at Fulfillment Status               Fulfilled at  \
# 0  2022-04-28 23:57:34 +0530          fulfilled  2022-04-29 11:31:50 +0530
# 1                        NaN          fulfilled  2022-04-29 11:27:54 +0530
# 2  2022-04-28 23:25:11 +0530          fulfilled  2022-04-29 11:31:50 +0530
# ...

# %%
csv2 = pd.read_csv("orders_export_2.csv")
csv2.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (28,60) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#      Name                       Email Financial Status  \
# 0  #14345  muneshchandra850@gmail.com             paid
# 1  #14344   kamalkhatri8888@gmail.com             paid
# 2  #14344   kamalkhatri8888@gmail.com              NaN
# 3  #14343    harshmaurya144@gmail.com             paid
# 4  #14342     asmita.jalali@gmail.com             paid
#
#                      Paid at Fulfillment Status               Fulfilled at  \
# 0  2022-01-28 00:10:31 +0530          fulfilled  2022-01-23 16:22:20 +0530
# 1  2022-01-27 18:11:21 +0530          fulfilled  2022-01-23 16:22:20 +0530
# 2                        NaN                NaN                        NaN
# 3  2022-01-28 00:10:32 +0530          fulfilled  2022-01-23 16:22:20 +0530
# ...

# %%
concate_data = pd.concat([csv1, csv2])

# %%
concate_data.head()
# Out:
#      Name                    Email Financial Status  \
# 0  #29914    pankajgavri@gmail.com             paid
# 1  #29913  aishpawar9428@gmail.com          pending
# 2  #29912    zuberali983@gmail.com             paid
# 3  #29911    zuberali983@gmail.com          pending
# 4  #29910  dr.ajaychauhan@yahoo.in          pending
#
#                      Paid at Fulfillment Status               Fulfilled at  \
# 0  2022-04-28 23:57:34 +0530          fulfilled  2022-04-29 11:31:50 +0530
# 1                        NaN          fulfilled  2022-04-29 11:27:54 +0530
# 2  2022-04-28 23:25:11 +0530          fulfilled  2022-04-29 11:31:50 +0530
# 3                        NaN          fulfilled  2022-04-29 11:31:50 +0530
# 4                        NaN          fulfilled  2022-04-29 11:31:50 +0530
#
#   Accepts Marketing Currency  Subtotal  Shipping  ...  Tax 5 Name  \
# 0                no      INR    719.10       0.0  ...         NaN
# ...

# %%
concate_data.to_csv("milk.csv")

# %%
concate_data
# Out:
#         Name                      Email Financial Status  \
# 0     #29914      pankajgavri@gmail.com             paid
# 1     #29913    aishpawar9428@gmail.com          pending
# 2     #29912      zuberali983@gmail.com             paid
# 3     #29911      zuberali983@gmail.com          pending
# 4     #29910    dr.ajaychauhan@yahoo.in          pending
# ...      ...                        ...              ...
# 9192   #6060  tiainla.tiainla@gmail.com          pending
# 9193   #6059   anmolkiran1512@gmail.com          pending
# 9194   #6058         jabstome@gmail.com             paid
# 9195   #6057         jabstome@gmail.com          pending
# 9196   #6056         jasys.js@gmail.com          pending
#
#                         Paid at Fulfillment Status               Fulfilled at  \
# 0     2022-04-28 23:57:34 +0530          fulfilled  2022-04-29 11:31:50 +0530
# 1                           NaN          fulfilled  2022-04-29 11:27:54 +0530
# ...

# %%
df = pd.read_csv("milk.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (29,46,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#        Unnamed: 0    Name                      Email Financial Status  \
# 0               0  #29914      pankajgavri@gmail.com             paid
# 1               1  #29913    aishpawar9428@gmail.com          pending
# 2               2  #29912      zuberali983@gmail.com             paid
# 3               3  #29911      zuberali983@gmail.com          pending
# 4               4  #29910    dr.ajaychauhan@yahoo.in          pending
# ...           ...     ...                        ...              ...
# 26533        9192   #6060  tiainla.tiainla@gmail.com          pending
# 26534        9193   #6059   anmolkiran1512@gmail.com          pending
# 26535        9194   #6058         jabstome@gmail.com             paid
# 26536        9195   #6057         jabstome@gmail.com          pending
# 26537        9196   #6056         jasys.js@gmail.com          pending
#
#                          Paid at Fulfillment Status  \
# 0      2022-04-28 23:57:34 +0530          fulfilled
# ...

# %%
filterdata = df[df['Financial Status'] == "paid"]

# %%
print(filterdata.shape)
filterdata.head()
# Out:
# (16036, 75)
#     Unnamed: 0    Name                       Email Financial Status  \
# 0            0  #29914       pankajgavri@gmail.com             paid
# 2            2  #29912       zuberali983@gmail.com             paid
# 8            8  #29906  bhumikagupta1011@gmail.com             paid
# 14          14  #29900        apstar0001@gmail.com             paid
# 17          17  #29897     kshitij_raj09@yahoo.com             paid
#
#                       Paid at Fulfillment Status               Fulfilled at  \
# 0   2022-04-28 23:57:34 +0530          fulfilled  2022-04-29 11:31:50 +0530
# 2   2022-04-28 23:25:11 +0530          fulfilled  2022-04-29 11:31:50 +0530
# 8   2022-04-28 22:04:47 +0530          fulfilled  2022-04-29 11:31:53 +0530
# 14  2022-04-28 21:13:27 +0530          fulfilled  2022-04-29 11:27:09 +0530
# 17  2022-04-28 20:59:03 +0530          fulfilled  2022-04-29 11:31:53 +0530
#
#    Accepts Marketing Currency  Subtotal  ...  Tax 5 Name  Tax 5 Value  Phone  \
# ...

# %%
df['birth_date'] = pd.to_datetime(filterdata['Fulfilled at'])
df
start_date = '29-03-2022' 
end_date = '29-04-2022'
mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)

# %%
df = df.loc[mask]
df
# Out:
#       Unnamed: 0    Name                                   Email  \
# 19            19  #29895  '+919143934415@neu-herbs.myshopify.com
# 55            55  #29865  '+918080784821@neu-herbs.myshopify.com
# 58            58  #29862                                     NaN
# 59            59  #29861                                     NaN
# 60            60  #29860                                     NaN
# ...          ...     ...                                     ...
# 6506        6506  #24111              ravikantsingh789@gmail.com
# 6659        6659  #23970                     chiragtnj@gmail.com
# 6662        6662  #23967                 rekha.dhumale@gmail.com
# 6838        6838  #23815              manpreetkaur1592@yahoo.com
# 6839        6839  #23814              deeptidwivedihdi@gmail.com
#
#      Financial Status                    Paid at Fulfillment Status  \
# 19               paid  2022-04-28 20:33:14 +0530          fulfilled
# ...

# %%
df.head()
# Out:
#     Unnamed: 0    Name                                   Email  \
# 19          19  #29895  '+919143934415@neu-herbs.myshopify.com
# 55          55  #29865  '+918080784821@neu-herbs.myshopify.com
# 58          58  #29862                                     NaN
# 59          59  #29861                                     NaN
# 60          60  #29860                                     NaN
#
#    Financial Status                    Paid at Fulfillment Status  \
# 19             paid  2022-04-28 20:33:14 +0530          fulfilled
# 55             paid  2022-04-28 16:44:42 +0530          fulfilled
# 58             paid  2022-04-28 16:20:43 +0530          fulfilled
# 59             paid  2022-04-28 16:20:42 +0530          fulfilled
# 60             paid  2022-04-28 16:20:40 +0530          fulfilled
#
#                  Fulfilled at Accepts Marketing Currency  Subtotal  ...  \
# 19  2022-04-28 22:24:06 +0530                no      INR    662.43  ...
# ...

# %%
filterdata = df[df['Lineitem name'] == "neuherbs Milk Thistle (Detox Formula) - Pack of 1 (60 Capsules)"]

# %%
#  products are : 
#

# %%
filterdata
# Out:
#       Unnamed: 0    Name                         Email Financial Status  \
# 713          713  #29271      naveenrana9271@gmail.com             paid
# 714          714  #29270    girish.patil0079@gmail.com             paid
# 780          780  #29211  Mithunchaudhary559@gmail.com             paid
# 796          796  #29197    augustinthomas55@gmail.com             paid
# 817          817  #29181   bijaysaikia212345@gmail.com             paid
# ...          ...     ...                           ...              ...
# 6106        6106  #24464     virenderdavgen5@gmail.com             paid
# 6154        6154  #24421        surinderlive@gmail.com             paid
# 6287        6287  #24298     debasisdutta008@gmail.com             paid
# 6354        6354  #24243        viksingh9176@gmail.com             paid
# 6360        6360  #24239        pandit.mani7@gmail.com             paid
#
#                         Paid at Fulfillment Status               Fulfilled at  \
# ...

# %%
k = input("give the file name : ")

filterdata.to_csv(f"{str(k)}.csv")
# Out:
# give the file name : m2

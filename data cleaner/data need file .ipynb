# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("m2.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    Name                         Email  \
# 0         713           713  #29271      naveenrana9271@gmail.com
# 1         714           714  #29270    girish.patil0079@gmail.com
# 2         780           780  #29211  Mithunchaudhary559@gmail.com
# 3         796           796  #29197    augustinthomas55@gmail.com
# 4         817           817  #29181   bijaysaikia212345@gmail.com
#
#   Financial Status                    Paid at Fulfillment Status  \
# 0             paid  2022-04-29 12:13:06 +0530          fulfilled
# 1             paid  2022-04-28 18:11:46 +0530          fulfilled
# 2             paid  2022-04-25 12:17:59 +0530          fulfilled
# 3             paid  2022-04-25 11:07:39 +0530          fulfilled
# 4             paid  2022-04-25 09:41:57 +0530          fulfilled
#
#                 Fulfilled at Accepts Marketing Currency  ...  Tax 5 Value  \
# 0  2022-04-25 18:02:29 +0530               yes      INR  ...          NaN
# ...

# %%
df.columns

# Email
# Phone
# First Name
# Last Name
# Country
# Zip
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Name', 'Email', 'Financial Status',
#        'Paid at', 'Fulfillment Status', 'Fulfilled at', 'Accepts Marketing',
#        'Currency', 'Subtotal', 'Shipping', 'Taxes', 'Total', 'Discount Code',
#        'Discount Amount', 'Shipping Method', 'Created at', 'Lineitem quantity',
#        'Lineitem name', 'Lineitem price', 'Lineitem compare at price',
#        'Lineitem sku', 'Lineitem requires shipping', 'Lineitem taxable',
#        'Lineitem fulfillment status', 'Billing Name', 'Billing Street',
#        'Billing Address1', 'Billing Address2', 'Billing Company',
#        'Billing City', 'Billing Zip', 'Billing Province', 'Billing Country',
#        'Billing Phone', 'Shipping Name', 'Shipping Street',
#        'Shipping Address1', 'Shipping Address2', 'Shipping Company',
#        'Shipping City', 'Shipping Zip', 'Shipping Province',
#        'Shipping Country', 'Shipping Phone', 'Notes', 'Note Attributes',
# ...

# %%
ll = ["birth_date","Unnamed: 0","Unnamed: 0.1",'Name','Financial Status', 'Paid at','Fulfillment Status', 'Fulfilled at', 'Accepts Marketing', 'Currency','Subtotal', 'Shipping', 'Taxes', 'Total', 'Discount Code','Discount Amount', 'Shipping Method', 'Created at', 'Lineitem quantity','Lineitem name', 'Lineitem price', 'Lineitem compare at price','Lineitem sku', 'Lineitem requires shipping', 'Lineitem taxable','Lineitem fulfillment status', 'Billing Street','Billing Address1', 'Billing Address2', 'Billing Company','Billing City', 'Billing Province', 'Shipping Name', 'Shipping Street','Shipping Address1', 'Shipping Address2', 'Shipping Company','Shipping City', 'Shipping Zip', 'Shipping Province','Shipping Country', 'Shipping Phone', 'Notes', 'Note Attributes','Cancelled at', 'Payment Method', 'Payment Reference','Refunded Amount', 'Vendor', 'Id', 'Tags', 'Risk Level', 'Source','Lineitem discount', 'Tax 1 Name', 'Tax 1 Value', 'Tax 2 Name','Tax 2 Value', 'Tax 3 Name', 'Tax 3 Value', 'Tax 4 Name', 'Tax 4 Value','Tax 5 Name', 'Tax 5 Value', 'Phone', 'Receipt Number', 'Duties','Billing Province Name', 'Shipping Province Name', 'Payment ID','Payment Terms Name', 'Next Payment Due At']

# %%
df = df.drop(ll, axis = 1)

# %%
df.loc[df['Billing Name'].str.split().str.len() == 2, 'first name'] = df['Billing Name'].str.split().str[0]
df
df.loc[df['Billing Name'].str.split().str.len() == 2, 'last name'] = df['Billing Name'].str.split().str[-1]
df
# Out:
#                             Email     Billing Name Billing Zip  \
# 0        naveenrana9271@gmail.com     Naveen Kumar     '181141
# 1      girish.patil0079@gmail.com     Girish Patil     '160017
# 2    Mithunchaudhary559@gmail.com              NaN         NaN
# 3      augustinthomas55@gmail.com              NaN         NaN
# 4     bijaysaikia212345@gmail.com              NaN         NaN
# ..                            ...              ...         ...
# 112     debasisdutta008@gmail.com  DEBASIS  DUTTA      '751002
# 113        viksingh9176@gmail.com     Vikram Singh     '854301
# 114        pandit.mani7@gmail.com    Manish Tiwari     '201303
# 115         pankaj.sptc@gmail.com   Pankaj  Kumar      '110051
# 116  gotoprashantmishra@gmail.com  Prashant Mishra     '110009
#
#     Billing Country Billing Phone first name last name
# 0                IN   80829 48831     Naveen     Kumar
# 1                IN   73079 52144     Girish     Patil
# ...

# %%
df.dropna()
# Out:
#                             Email       Billing Name Billing Zip  \
# 0        naveenrana9271@gmail.com       Naveen Kumar     '181141
# 1      girish.patil0079@gmail.com       Girish Patil     '160017
# 5       divyapreetkaur1@gmail.com  Lakhwinder  Singh     '147001
# 8        rohitsehal.555@gmail.com       Rohit Sehgal     '140401
# 9            judo.abhay@gmail.com   Abhayjeet  Singh     '335512
# ..                            ...                ...         ...
# 112     debasisdutta008@gmail.com    DEBASIS  DUTTA      '751002
# 113        viksingh9176@gmail.com       Vikram Singh     '854301
# 114        pandit.mani7@gmail.com      Manish Tiwari     '201303
# 115         pankaj.sptc@gmail.com     Pankaj  Kumar      '110051
# 116  gotoprashantmishra@gmail.com    Prashant Mishra     '110009
#
#     Billing Country     Billing Phone  first name last name
# 0                IN       80829 48831      Naveen     Kumar
# 1                IN       73079 52144      Girish     Patil
# ...

# %%
df = df.dropna()

# %%
df.to_csv("main_milk.csv")

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("main.csv")

# %%
df
# Out:
#                               Email          Phone First Name Last Name  \
# 0         jyotisahnisolan@gmail.com     8278860168      Jyoti     Sahni
# 1          diptygupta2013@gmail.com  +919971560943      Dipty     Gupta
# 2            uttamsahu131@gmail.com    81098 79099      Uttam      Sahu
# 3               pgirbaudn@gmail.com   099175 29646     Palden   Namgyal
# 4      manmohanmishra7575@gmail.com     8318301660   Manmohan    Mishra
# ...                             ...            ...        ...       ...
# 34536       barbeeangel00@gmail.com     8756014588       JUHI    Babbar
# 34537          gopi_satya@yahoo.com    91777 71435      Satua         M
# 34538          sahitya.mj@gmail.com     9686867621   Sahithya       M.a
# 34539        raokamal1997@gmail.com            NaN        NaN       NaN
# 34540      koolhorizon111@gmail.com            NaN        NaN       NaN
#
#       Country     Zip
# 0       India  173212
# 1       India  110092
# 2       India  493449
# ...

# %%
df.drop_duplicates(subset =["Email","Phone"], keep = False, inplace = True)

# %%
df
# Out:
#                             Email          Phone  First Name Last Name  \
# 0       jyotisahnisolan@gmail.com     8278860168       Jyoti     Sahni
# 39            website@roihunt.com    83769 96952       kumar    Gaurav
# 40       abhaysinghzone@gmail.com    99993 58933  Abhay(Test     Singh
# 41     subhash.yadav@neuherbs.com    96507 65665     Subhash     Yadav
# 42                            NaN  +919650765665     subhash     yadav
# ...                           ...            ...         ...       ...
# 34536     barbeeangel00@gmail.com     8756014588        JUHI    Babbar
# 34537        gopi_satya@yahoo.com    91777 71435       Satua         M
# 34538        sahitya.mj@gmail.com     9686867621    Sahithya       M.a
# 34539      raokamal1997@gmail.com            NaN         NaN       NaN
# 34540    koolhorizon111@gmail.com            NaN         NaN       NaN
#
#       Country     Zip
# 0       India  173212
# 39      India  121001
# 40      India  201002
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#                             Email        Phone   First Name Last Name Country  \
# 0       jyotisahnisolan@gmail.com   8278860168        Jyoti     Sahni   India
# 39            website@roihunt.com  83769 96952        kumar    Gaurav   India
# 40       abhaysinghzone@gmail.com  99993 58933   Abhay(Test     Singh   India
# 41     subhash.yadav@neuherbs.com  96507 65665      Subhash     Yadav   India
# 43             bindec96@gmail.com  98477 00409  Sreelakshmi   M Mohan   India
# ...                           ...          ...          ...       ...     ...
# 34534    tabassumnsr381@gmail.com  94567 38399     Tabassum    Ansari   India
# 34535      cmarialavina@gmail.com  74062 57476       Lavina   Cardozo   India
# 34536     barbeeangel00@gmail.com   8756014588         JUHI    Babbar   India
# 34537        gopi_satya@yahoo.com  91777 71435        Satua         M   India
# 34538        sahitya.mj@gmail.com   9686867621     Sahithya       M.a   India
#
#           Zip
# 0      173212
# ...

# %%
df.to_csv("out.csv")

# %%
list1 = []
for i in df["Phone"]:
    summ = 0
#     for j in i:
#         summ+=1
#     if summ==10:
#         k = ((i.strip()).replace(" ", ""))
#         list1.append(k)
    if "+91" in i:
        k = ((i[3:].strip()).replace(" ", ""))
        list1.append(k)
    elif:
        for j in i:
        summ+=1
        if summ==10:
#         k = ((i.strip()).replace(" ", ""))
        list1.append("NaN")
        
    else:
        k = (i.strip()).replace(" ", "")
        list1.append(k)
# Out:
#   File "<ipython-input-67-846abd2a56c5>", line 12
#     elif:
#         ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#                             Email        Phone   First Name Last Name Country  \
# 0       jyotisahnisolan@gmail.com   8278860168        Jyoti     Sahni   India
# 39            website@roihunt.com  83769 96952        kumar    Gaurav   India
# 40       abhaysinghzone@gmail.com  99993 58933   Abhay(Test     Singh   India
# 41     subhash.yadav@neuherbs.com  96507 65665      Subhash     Yadav   India
# 43             bindec96@gmail.com  98477 00409  Sreelakshmi   M Mohan   India
# ...                           ...          ...          ...       ...     ...
# 34534    tabassumnsr381@gmail.com  94567 38399     Tabassum    Ansari   India
# 34535      cmarialavina@gmail.com  74062 57476       Lavina   Cardozo   India
# 34536     barbeeangel00@gmail.com   8756014588         JUHI    Babbar   India
# 34537        gopi_satya@yahoo.com  91777 71435        Satua         M   India
# 34538        sahitya.mj@gmail.com   9686867621     Sahithya       M.a   India
#
#           Zip clean_Phone
# ...

# %%
df['clean_Phone'] = list1
# Out:
# <ipython-input-69-27004dbd2950>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_Phone'] = list1

# %%
df
# Out:
#                             Email        Phone   First Name Last Name Country  \
# 0       jyotisahnisolan@gmail.com   8278860168        Jyoti     Sahni   India
# 39            website@roihunt.com  83769 96952        kumar    Gaurav   India
# 40       abhaysinghzone@gmail.com  99993 58933   Abhay(Test     Singh   India
# 41     subhash.yadav@neuherbs.com  96507 65665      Subhash     Yadav   India
# 43             bindec96@gmail.com  98477 00409  Sreelakshmi   M Mohan   India
# ...                           ...          ...          ...       ...     ...
# 34534    tabassumnsr381@gmail.com  94567 38399     Tabassum    Ansari   India
# 34535      cmarialavina@gmail.com  74062 57476       Lavina   Cardozo   India
# 34536     barbeeangel00@gmail.com   8756014588         JUHI    Babbar   India
# 34537        gopi_satya@yahoo.com  91777 71435        Satua         M   India
# 34538        sahitya.mj@gmail.com   9686867621     Sahithya       M.a   India
#
#           Zip clean_Phone
# ...

# %%
df.dropna()
# Out:
#                             Email        Phone   First Name Last Name Country  \
# 0       jyotisahnisolan@gmail.com   8278860168        Jyoti     Sahni   India
# 39            website@roihunt.com  83769 96952        kumar    Gaurav   India
# 40       abhaysinghzone@gmail.com  99993 58933   Abhay(Test     Singh   India
# 41     subhash.yadav@neuherbs.com  96507 65665      Subhash     Yadav   India
# 43             bindec96@gmail.com  98477 00409  Sreelakshmi   M Mohan   India
# ...                           ...          ...          ...       ...     ...
# 34534    tabassumnsr381@gmail.com  94567 38399     Tabassum    Ansari   India
# 34535      cmarialavina@gmail.com  74062 57476       Lavina   Cardozo   India
# 34536     barbeeangel00@gmail.com   8756014588         JUHI    Babbar   India
# 34537        gopi_satya@yahoo.com  91777 71435        Satua         M   India
# 34538        sahitya.mj@gmail.com   9686867621     Sahithya       M.a   India
#
#           Zip clean_Phone
# ...
